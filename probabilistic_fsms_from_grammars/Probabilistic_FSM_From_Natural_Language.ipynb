# %%
import pandas as pd
import numpy as np
import json
import spacy
import ast
import pickle
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import torch
import os
from collections import defaultdict
from scipy.stats import entropy
from scipy.spatial.distance import jensenshannon

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Load Gutenberg Dataset

# %%
with open("/content/drive/MyDrive/gutenberg_data.pkl","rb") as f:
    gutenberg_df = pickle.load(f)

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ### Tag Documents

# %%
def tag_full_document(text):
    '''
    Retrieve part of speech tags for a full document
    '''
    doc = nlp(text)
    return [[(token.text, token.pos_, idx) for idx, token in enumerate(sent)] for sent in doc.sents]
    return tagged_sentences

# %%
# Todo: Extract part of speech tags for more than 1 document
tagged_sentences = tag_full_document(gutenberg_df.iloc[0]['Text'])

# %% [markdown]
# ### Extract N-Grams

# %%
def extract_ngrams_from_sentences(ngram_size, tagged_sentences):
    '''
    Extract ngrams from a list of tagged sentences
    '''
    results = []
    for sent_idx, tagged_sentence in enumerate(tagged_sentences):
       if len(tagged_sentence) < ngram_size:
          continue
       for i in range(len(tagged_sentence) - (ngram_size -1)):
          extracted_ngram = tagged_sentence[i:i+ngram_size]
          results.append((sent_idx, i, extracted_ngram))
    return results

# %%
text_ngrams = extract_ngrams_from_sentences(3, tagged_sentences)

# %% [markdown]
# ### Next Token Generation

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2', device="cuda")
tokenizer.add_special_tokens({'pad_token': '[PAD]'})
# Resize model embeddings to accommodate the new token
model = GPT2LMHeadModel.from_pretrained('gpt2').to("cuda")
model.resize_token_embeddings(len(tokenizer))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# Embedding(50258, 768)

# %%
text_segments = []
for ngram in text_ngrams:
  text_segments.append(" ".join([token[0] for token in ngram[2]]))

# %%
text_encodings = tokenizer(text_segments, truncation=True, padding=True,return_tensors="pt")

# %%
input_ids = text_encodings['input_ids']
attention_mask = text_encodings['attention_mask']
batch_size = 1024
generated_outputs = []
for i in range(0, len(input_ids), batch_size):
    batch_input_ids = input_ids[i:i+batch_size].to("cuda")
    batch_attention_mask = attention_mask[i:i+batch_size].to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            input_ids=batch_input_ids,
            attention_mask=batch_attention_mask,
            max_new_tokens=1,
            temperature=0.5,
            do_sample=True,
            return_dict_in_generate=True,
            output_scores=True,
            pad_token_id=tokenizer.pad_token_id
        )
    generated_outputs.append(outputs.sequences.cpu())
# Out:
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.

# %%
generated_outputs = torch.cat(generated_outputs, dim=0)

# %%
next_word_tokens = tokenizer.batch_decode(generated_outputs[:,-1], skip_special_tokens=True)

# %% [markdown]
# ### Build Probability Matrix of POS Predictions

# %%
def get_next_word_pos(sentence, next_word, ngram_position, ngram_size):
  '''
  Get the part of speech tag for the next word in a sentence
  '''
  sentence_tokens = [word for word, pos, _ in sentence]
  extended_sentence = sentence_tokens[:ngram_position+ngram_size] + [next_word]

  tagged = tag_full_document(" ".join(extended_sentence))
  return tagged[-1][-1][1]

# %%
transition_matrix = defaultdict(lambda: defaultdict(int))

# %%
for ngram, next_word in zip(text_ngrams, next_word_tokens):
  sent_idx = ngram[0]
  ngram_position = ngram[1]
  sentence = tagged_sentences[sent_idx]
  next_word_pos = get_next_word_pos(sentence, next_word, ngram_position, 3)
  pos_ngram = "->".join([token[1] for token in ngram[2]])
  transition_matrix[pos_ngram][next_word_pos] += 1

# %%
for ngram, pos_counts in transition_matrix.items():
   total = sum(pos_counts.values())
   for pos, count in pos_counts.items():
       transition_matrix[ngram][pos] = count / total

# %%
transition_df = pd.DataFrame(transition_matrix).transpose().fillna(0)

# %% [markdown]
# ## POS TAG Meanings
# * ADJ: Adjective
# * ADP: Adposition
# * ADV: Adverb
# * AUX: Auxiliary
# * CONJ: Conjunction
# * CCONJ: Coordinating conjunction
# * DET: Determiner
# * INTJ: Interjection
# * NOUN: Noun
# * NUM: Numeral
# * PART: Particle
# * PRON: Pronoun
# * PUNCT: Punctuation
# * SCONJ: Subordinating conjunction
# * SPACE: Space
# * SYM: Symbol
# * VERB: Verb
# * X: Other
# * EOL: End of line

# %%
transition_df
# Out:
#                         PUNCT     PROPN       AUX      PART     SPACE  \
# NOUN->PROPN->PROPN   0.472222  0.333333  0.027778  0.027778  0.083333
# PROPN->PROPN->PUNCT  0.656250  0.118750  0.040625  0.006250  0.018750
# PROPN->PUNCT->PROPN  0.751678  0.067114  0.000000  0.006711  0.046980
# PUNCT->PROPN->NOUN   0.562500  0.125000  0.000000  0.000000  0.125000
# PROPN->NOUN->CCONJ   0.000000  0.000000  0.000000  0.000000  0.000000
# ...                       ...       ...       ...       ...       ...
# PRON->ADV->PROPN     1.000000  0.000000  0.000000  0.000000  0.000000
# ADP->PUNCT->X        1.000000  0.000000  0.000000  0.000000  0.000000
# PROPN->NUM->SYM      1.000000  0.000000  0.000000  0.000000  0.000000
# NUM->SYM->NUM        1.000000  0.000000  0.000000  0.000000  0.000000
# SYM->NUM->PROPN      0.000000  0.000000  0.000000  0.000000  0.000000
#
#                          VERB     CCONJ       ADJ      NOUN      PRON  \
# NOUN->PROPN->PROPN   0.027778  0.027778  0.000000  0.000000  0.000000
# PROPN->PROPN->PUNCT  0.031250  0.012500  0.015625  0.078125  0.015625
# PROPN->PUNCT->PROPN  0.013423  0.000000  0.000000  0.060403  0.006711
# PUNCT->PROPN->NOUN   0.000000  0.062500  0.000000  0.125000  0.000000
# PROPN->NOUN->CCONJ   0.000000  0.000000  0.000000  0.000000  0.600000
# ...                       ...       ...       ...       ...       ...
# PRON->ADV->PROPN     0.000000  0.000000  0.000000  0.000000  0.000000
# ADP->PUNCT->X        0.000000  0.000000  0.000000  0.000000  0.000000
# PROPN->NUM->SYM      0.000000  0.000000  0.000000  0.000000  0.000000
# NUM->SYM->NUM        0.000000  0.000000  0.000000  0.000000  0.000000
# SYM->NUM->PROPN      0.000000  0.000000  0.000000  0.000000  0.000000
#
#                           ADP       NUM       ADV      INTJ  SCONJ    X  SYM  \
# NOUN->PROPN->PROPN   0.000000  0.000000  0.000000  0.000000    0.0  0.0  0.0
# PROPN->PROPN->PUNCT  0.003125  0.003125  0.000000  0.000000    0.0  0.0  0.0
# PROPN->PUNCT->PROPN  0.013423  0.006711  0.020134  0.006711    0.0  0.0  0.0
# PUNCT->PROPN->NOUN   0.000000  0.000000  0.000000  0.000000    0.0  0.0  0.0
# PROPN->NOUN->CCONJ   0.200000  0.000000  0.000000  0.000000    0.2  0.0  0.0
# ...                       ...       ...       ...       ...    ...  ...  ...
# PRON->ADV->PROPN     0.000000  0.000000  0.000000  0.000000    0.0  0.0  0.0
# ADP->PUNCT->X        0.000000  0.000000  0.000000  0.000000    0.0  0.0  0.0
# PROPN->NUM->SYM      0.000000  0.000000  0.000000  0.000000    0.0  0.0  0.0
# NUM->SYM->NUM        0.000000  0.000000  0.000000  0.000000    0.0  0.0  0.0
# SYM->NUM->PROPN      0.000000  1.000000  0.000000  0.000000    0.0  0.0  0.0
#
#                      DET
# NOUN->PROPN->PROPN   0.0
# PROPN->PROPN->PUNCT  0.0
# PROPN->PUNCT->PROPN  0.0
# PUNCT->PROPN->NOUN   0.0
# PROPN->NOUN->CCONJ   0.0
# ...                  ...
# PRON->ADV->PROPN     0.0
# ADP->PUNCT->X        0.0
# PROPN->NUM->SYM      0.0
# NUM->SYM->NUM        0.0
# SYM->NUM->PROPN      0.0
#
# [1980 rows x 18 columns]

# %%
transition_df.to_csv('/content/drive/MyDrive/transition_probs.csv')

# %%
#transition_df = pd.read_csv('/content/drive/MyDrive/transition_probs.csv')

# %% [markdown]
# ### Build Ground Truth Probability Matrix

# %%
def extract_ngram_ground_truth_pairings(ngram_size, tagged_sentences):
    '''
    Extract ngrams from a list of tagged sentences
    '''
    ngram_pairs = []
    for sent_idx, tagged_sentence in enumerate(tagged_sentences):
       if len(tagged_sentence) < ngram_size:
          continue

       for i in range(len(tagged_sentence) - (ngram_size -1)):
          extracted_ngram = tagged_sentence[i:i+ngram_size]
          next_word = tagged_sentence[i + ngram_size] if (i + ngram_size) < len(tagged_sentence) else None
          ngram_pairs.append((extracted_ngram, next_word))
    return ngram_pairs

# %%
ngrams_with_next = extract_ngram_ground_truth_pairings(3, tagged_sentences)

# %%
gt_transition_matrix = defaultdict(lambda: defaultdict(int))

# %%
for ngram, next_word in ngrams_with_next:
  pos_ngram = "->".join([token[1] for token in ngram])
  next_word_pos = next_word[1] if next_word else 'NONE'
  gt_transition_matrix[pos_ngram][next_word_pos] += 1

# %%
for ngram, pos_counts in gt_transition_matrix.items():
   total = sum(pos_counts.values())
   for pos, count in pos_counts.items():
       gt_transition_matrix[ngram][pos] = count / total

# %%
gt_transition_df = pd.DataFrame(gt_transition_matrix).transpose().fillna(0)

# %%
gt_transition_df.to_csv('/content/drive/MyDrive/gt_transition_probs.csv')

# %% [markdown]
# ### Calculate KL Divergence

# %%
gt_transition_df['SPACE'] = 0.0
transition_df['NONE'] = 0.0

# %%
columns = sorted(gt_transition_df.columns)

# %%
def compute_kl_divergence(real_matrix, generated_matrix, epsilon=1e-10):
   kl_scores = {}

   for ngram in real_matrix.index:
      if ngram in generated_matrix.index:
         real_probs = real_matrix.loc[ngram].values
         gen_probs = generated_matrix.loc[ngram].values

         real_sum = real_probs.sum()
         gen_sum = gen_probs.sum()

         if real_sum == 0 or gen_sum == 0:
            kl_scores[ngram] = 0.0
            continue

         real_probs = real_probs / real_sum
         gen_probs = gen_probs / gen_sum

         gen_probs = np.clip(gen_probs, epsilon, 1)

         kl_scores[ngram] = entropy(real_probs, gen_probs)
   return kl_scores

# %%
def compute_js_divergence(real_matrix, generated_matrix, epsilon=1e-10):
    """
    Compute Jensen-Shannon divergence between real and generated POS probability matrices.
    """
    js_scores = {}

    for ngram in real_matrix.index:
        if ngram in generated_matrix.index:
            real_probs = real_matrix.loc[ngram].values
            gen_probs = generated_matrix.loc[ngram].values

            real_sum = real_probs.sum()
            gen_sum = gen_probs.sum()

            if real_sum == 0 or gen_sum == 0:
              js_scores[ngram] = 0.0
              continue


            real_probs = real_probs / real_sum
            gen_probs = gen_probs / gen_sum

            gen_probs = np.clip(gen_probs, epsilon, 1)

            js_scores[ngram] = jensenshannon(real_probs, gen_probs)

    return js_scores

# %%
kl_scores = compute_kl_divergence(gt_transition_df[columns], transition_df[columns])

# %%
js_scores = compute_js_divergence(gt_transition_df[columns], transition_df[columns])

# %%
kl_srs = pd.Series(kl_scores)

# %%
kl_srs
# Out:
# NOUN->PROPN->PROPN     3.698803e+00
# PROPN->PROPN->PUNCT    6.107894e+00
# PROPN->PUNCT->PROPN    1.395041e+00
# PUNCT->PROPN->NOUN     9.148484e+00
# PROPN->NOUN->CCONJ     2.252545e+01
#                            ...
# PRON->ADV->PROPN       1.800000e-09
# ADP->PUNCT->X          2.302585e+01
# PROPN->NUM->SYM        2.302585e+01
# NUM->SYM->NUM          2.302585e+01
# SYM->NUM->PROPN        2.302585e+01
# Length: 1980, dtype: float64

# %%
js_scores
# Out:
# {'NOUN->PROPN->PROPN': np.float64(0.4073453827469874),
#  'PROPN->PROPN->PUNCT': np.float64(0.5284400269091707),
#  'PROPN->PUNCT->PROPN': np.float64(0.34522640502901875),
#  'PUNCT->PROPN->NOUN': np.float64(0.5315173435567584),
#  'PROPN->NOUN->CCONJ': np.float64(0.8325546097698271),
#  'NOUN->CCONJ->DET': np.float64(0.6115533826321826),
#  'CCONJ->DET->PROPN': np.float64(0.48654150659348533),
#  'DET->PROPN->PROPN': np.float64(0.3381422297224149),
#  'PROPN->PROPN->PROPN': np.float64(0.2362895649418511),
#  'PROPN->PROPN->ADP': np.float64(0.49939047660890057),
#  'PROPN->ADP->PUNCT': np.float64(0.8325546104362479),
#  'ADP->PUNCT->PROPN': np.float64(0.70493199911893),
#  'PUNCT->PROPN->PROPN': np.float64(0.3045061231170285),
#  'PROPN->PUNCT->PUNCT': np.float64(0.690465229881249),
#  'PUNCT->PUNCT->PUNCT': np.float64(0.7073573346788002),
#  'PUNCT->PUNCT->PROPN': np.float64(0.42149058628773683),
#  'PUNCT->PROPN->PUNCT': np.float64(0.5239177064635269),
#  'PUNCT->PUNCT->NOUN': np.float64(0.44084323042865076),
#  'PUNCT->NOUN->ADP': np.float64(0.6150509515737073),
#  'NOUN->ADP->PROPN': np.float64(0.3216199038301662),
#  'ADP->PROPN->PUNCT': np.float64(0.6061918995838601),
#  'PUNCT->PUNCT->ADJ': np.float64(0.3929934600166744),
#  'PUNCT->ADJ->NOUN': np.float64(0.26004148125855997),
#  'ADJ->NOUN->PUNCT': np.float64(0.603019708716758),
#  'NOUN->PUNCT->PUNCT': np.float64(0.724909967037314),
#  'PROPN->ADP->PROPN': np.float64(0.33213348158033684),
#  'PROPN->NOUN->ADP': np.float64(0.5418348297768332),
#  'ADP->PROPN->CCONJ': np.float64(0.591256786738059),
#  'PROPN->CCONJ->PROPN': np.float64(0.38696454833461524),
#  'CCONJ->PROPN->PUNCT': np.float64(0.6355497358810802),
#  'PUNCT->NOUN->CCONJ': np.float64(0.5146203822718419),
#  'NOUN->CCONJ->PRON': np.float64(0.37415306655165986),
#  'CCONJ->PRON->NOUN': np.float64(0.44222412217198726),
#  'PRON->NOUN->PUNCT': np.float64(0.5775254743785949),
#  'PUNCT->PUNCT->ADP': np.float64(0.7157696365564697),
#  'PUNCT->ADP->PROPN': np.float64(0.39750733196303256),
#  'ADP->PROPN->PART': np.float64(0.599809599255048),
#  'PROPN->PART->NOUN': np.float64(0.32967826892954),
#  'PART->NOUN->PUNCT': np.float64(0.594937646749484),
#  'PUNCT->PUNCT->DET': np.float64(0.6933194098086521),
#  'PUNCT->DET->ADJ': np.float64(0.4014313426261612),
#  'DET->ADJ->PROPN': np.float64(0.33193032913855036),
#  'ADJ->PROPN->PUNCT': np.float64(0.6396713467822117),
#  'PUNCT->PROPN->DET': np.float64(0.832554610436248),
#  'PROPN->DET->PROPN': np.float64(0.46400132994771953),
#  'DET->PROPN->PUNCT': np.float64(0.6164558662734345),
#  'PROPN->PROPN->PART': np.float64(0.6138677861281242),
#  'PROPN->PROPN->CCONJ': np.float64(0.410822105800684),
#  'PUNCT->PROPN->NUM': np.float64(0.7210134417965528),
#  'PROPN->NUM->NOUN': np.float64(0.48067562807455133),
#  'NUM->NOUN->PROPN': np.float64(0.7461576804620775),
#  'NOUN->PROPN->VERB': np.float64(0.48067562689935717),
#  'PROPN->VERB->PROPN': np.float64(0.5429402523300149),
#  'VERB->PROPN->PUNCT': np.float64(0.6263375148199722),
#  'PROPN->PUNCT->NUM': np.float64(0.4229710598452608),
#  'PUNCT->NUM->PUNCT': np.float64(0.5758871485162459),
#  'NUM->PUNCT->PROPN': np.float64(0.6741323054957116),
#  'SCONJ->ADJ->NOUN': np.float64(0.4183186566889891),
#  'NOUN->PUNCT->ADP': np.float64(0.5796177546851218),
#  'PUNCT->ADP->DET': np.float64(0.45134549036705973),
#  'ADP->DET->PRON': np.float64(0.15579246293024498),
#  'DET->PRON->NOUN': np.float64(0.25608769959609406),
#  'NOUN->PUNCT->VERB': np.float64(0.5205438638603028),
#  'PUNCT->VERB->DET': np.float64(0.5797137612529959),
#  'VERB->DET->ADJ': np.float64(0.36198726384991436),
#  'DET->ADJ->NOUN': np.float64(0.22989976657064298),
#  'NOUN->PUNCT->ADV': np.float64(0.4602421407343682),
#  'PUNCT->ADV->NOUN': np.float64(0.5481198735358469),
#  'ADV->NOUN->PUNCT': np.float64(0.6468762095444216),
#  'NOUN->PUNCT->PRON': np.float64(0.4067764528820089),
#  'PUNCT->PRON->ADP': np.float64(0.40727775714663117),
#  'PRON->ADP->NOUN': np.float64(0.3785182597602704),
#  'ADP->NOUN->ADV': np.float64(0.6248551302857159),
#  'NOUN->ADV->ADV': np.float64(0.4078747467880208),
#  'ADV->ADV->ADJ': np.float64(0.28719782233504393),
#  'ADV->ADJ->PUNCT': np.float64(0.5424577793496417),
#  'ADJ->PUNCT->INTJ': np.float64(0.46450140452505184),
#  'PUNCT->INTJ->PUNCT': np.float64(0.5565936224134053),
#  'INTJ->PUNCT->ADJ': np.float64(0.6122826906413539),
#  'PUNCT->ADJ->ADJ': np.float64(0.5417561714278312),
#  'ADJ->ADJ->NOUN': np.float64(0.3498952402005351),
#  'ADJ->NOUN->ADV': np.float64(0.4107895860248909),
#  'NOUN->ADV->PUNCT': np.float64(0.602586227832984),
#  'PRON->PRON->ADP': np.float64(0.7600148985892085),
#  'PRON->ADP->DET': np.float64(0.5826637165373787),
#  'ADP->DET->NOUN': np.float64(0.19479324183607083),
#  'DET->NOUN->VERB': np.float64(0.3000003172711794),
#  'NOUN->VERB->DET': np.float64(0.5018176857338458),
#  'VERB->DET->NOUN': np.float64(0.19824549265759295),
#  'DET->NOUN->ADP': np.float64(0.5659476852434824),
#  'NOUN->ADP->DET': np.float64(0.4655431201482613),
#  'DET->NOUN->PUNCT': np.float64(0.5907787646983167),
#  'NOUN->PUNCT->AUX': np.float64(0.55487575661094),
#  'PUNCT->AUX->VERB': np.float64(0.2909598278674621),
#  'AUX->VERB->PRON': np.float64(0.28307591127964093),
#  'VERB->PRON->ADP': np.float64(0.5383297941474731),
#  'PRON->ADP->PRON': np.float64(0.25576860826469555),
#  'ADP->PRON->PART': np.float64(0.6926813083674564),
#  'PRON->PART->VERB': np.float64(0.3654125260566861),
#  'PART->VERB->DET': np.float64(0.5377096322824086),
#  'PRON->VERB->DET': np.float64(0.5372837776456771),
#  'ADP->PROPN->PRON': np.float64(0.41487657351814466),
#  'PROPN->PRON->VERB': np.float64(0.538582413970652),
#  'PRON->VERB->NUM': np.float64(0.215088914943321),
#  'VERB->NUM->ADP': np.float64(0.8325546097698272),
#  'NUM->ADP->VERB': np.float64(0.8325546104362479),
#  'ADP->VERB->DET': np.float64(0.5213728428568359),
#  'DET->NOUN->AUX': np.float64(0.5545113813410149),
#  'NOUN->AUX->DET': np.float64(0.5270250944755135),
#  'AUX->DET->ADJ': np.float64(0.40815784772007024),
#  'NOUN->PUNCT->DET': np.float64(0.622230545688218),
#  'PUNCT->DET->NOUN': np.float64(0.2676667371607548),
#  'NOUN->VERB->ADP': np.float64(0.5143656761528452),
#  'VERB->ADP->DET': np.float64(0.5225493979135355),
#  'VERB->PUNCT->ADV': np.float64(0.47554843740453473),
#  'PUNCT->ADV->PUNCT': np.float64(0.5686435473835594),
#  'ADV->PUNCT->ADV': np.float64(0.4582763781825185),
#  'PUNCT->ADV->ADP': np.float64(0.5706392510398854),
#  'ADV->ADP->DET': np.float64(0.5696014978396576),
#  'NOUN->ADP->NOUN': np.float64(0.2606898753377491),
#  'ADP->NOUN->PUNCT': np.float64(0.5905833079334619),
#  'NOUN->PUNCT->SCONJ': np.float64(0.566512834008505),
#  'PUNCT->SCONJ->PRON': np.float64(0.22288505573353004),
#  'SCONJ->PRON->VERB': np.float64(0.3622700968729057),
#  'ADP->DET->ADJ': np.float64(0.3376809417076273),
#  'ADJ->NOUN->ADP': np.float64(0.5368759594649881),
#  'DET->NOUN->DET': np.float64(0.5604244028719206),
#  'NOUN->DET->DET': np.float64(0.8325546104362479),
#  'DET->DET->NOUN': np.float64(0.2810231709578129),
#  'NOUN->AUX->VERB': np.float64(0.2744473035625351),
#  'AUX->VERB->PUNCT': np.float64(0.5551155454403798),
#  'VERB->PUNCT->ADP': np.float64(0.6109255491156886),
#  'PUNCT->ADP->NOUN': np.float64(0.4091717723082172),
#  'NOUN->PUNCT->CCONJ': np.float64(0.561335654213728),
#  'PUNCT->CCONJ->ADP': np.float64(0.4720446178411294),
#  'CCONJ->ADP->NOUN': np.float64(0.4109219665954968),
#  'ADP->NOUN->ADP': np.float64(0.4926706914651254),
#  'PUNCT->PRON->VERB': np.float64(0.35021353739978583),
#  'PRON->VERB->ADP': np.float64(0.47355421677408743),
#  'VERB->ADP->NOUN': np.float64(0.27350772896342723),
#  'ADP->NOUN->DET': np.float64(0.6202865697936519),
#  'NOUN->DET->PRON': np.float64(0.5887050095851101),
#  'PUNCT->CCONJ->SCONJ': np.float64(0.4754328027260004),
#  'CCONJ->SCONJ->ADV': np.float64(0.6842610024350283),
#  'SCONJ->ADV->ADJ': np.float64(0.3033947679124417),
#  'ADV->ADJ->PART': np.float64(0.5747201936373804),
#  'ADJ->PART->VERB': np.float64(0.33600510873308964),
#  'PART->VERB->PRON': np.float64(0.25721241916883875),
#  'VERB->PRON->AUX': np.float64(0.43456215341871907),
#  'PRON->AUX->VERB': np.float64(0.27401835304264577),
#  'AUX->VERB->ADP': np.float64(0.5217146514384732),
#  'NOUN->ADP->ADV': np.float64(0.6162803217650037),
#  'ADP->ADV->DET': np.float64(0.7100049565308497),
#  'ADV->DET->NOUN': np.float64(0.38173076329761985),
#  'ADP->DET->ADV': np.float64(0.5185582763285908),
#  'DET->ADV->PUNCT': np.float64(0.7872123194393802),
#  'ADV->PUNCT->VERB': np.float64(0.5289644074882303),
#  'PUNCT->VERB->NOUN': np.float64(0.28625525583224826),
#  'VERB->NOUN->PUNCT': np.float64(0.5845261764035634),
#  'CCONJ->SCONJ->NOUN': np.float64(0.4369831242786523),
#  'SCONJ->NOUN->VERB': np.float64(0.5684166113519312),
#  'NOUN->VERB->PROPN': np.float64(0.42350279215996867),
#  'VERB->PROPN->PART': np.float64(0.8325546091166669),
#  'PROPN->PART->NUM': np.float64(0.5887050105170882),
#  'PART->NUM->PRON': np.float64(0.832554610436248),
#  'NUM->PRON->PUNCT': np.float64(0.8325546104362479),
#  'PRON->PUNCT->ADP': np.float64(0.5611034305019447),
#  'PUNCT->ADP->NUM': np.float64(0.3633671627280262),
#  'ADP->NUM->PUNCT': np.float64(0.6206661492806039),
#  'NUM->PUNCT->VERB': np.float64(0.6006095554633643),
#  'PUNCT->VERB->PRON': np.float64(0.26311273060367835),
#  'VERB->PRON->PART': np.float64(0.5051567844544728),
#  'PRON->PART->AUX': np.float64(0.5680430793352562),
#  'PART->AUX->PUNCT': np.float64(0.7086557189291431),
#  'AUX->PUNCT->CCONJ': np.float64(0.5904104156079495),
#  'PUNCT->CCONJ->ADV': np.float64(0.5150866584168134),
#  'CCONJ->ADV->DET': np.float64(0.7150484143020814),
#  'ADV->DET->PROPN': np.float64(0.5230096525605428),
#  'PROPN->PROPN->NOUN': np.float64(0.4655339122757581),
#  'PUNCT->ADV->ADV': np.float64(0.41421079055826665),
#  'ADV->ADV->DET': np.float64(0.6573340650694527),
#  'PROPN->PUNCT->DET': np.float64(0.6500483118364331),
#  'NOUN->ADP->PRON': np.float64(0.21473921498153958),
#  'ADP->PRON->NOUN': np.float64(0.21560250678504647),
#  'PRON->NOUN->CCONJ': np.float64(0.4340107260838352),
#  'NOUN->CCONJ->NOUN': np.float64(0.23261686723172095),
#  'CCONJ->NOUN->VERB': np.float64(0.6364276234769811),
#  'DET->NOUN->SCONJ': np.float64(0.6364816884205585),
#  'NOUN->SCONJ->PRON': np.float64(0.35255810806963894),
#  'SCONJ->PRON->AUX': np.float64(0.4600882422017079),
#  'PRON->AUX->ADV': np.float64(0.5068779077935446),
#  'AUX->ADV->CCONJ': np.float64(0.7210134418025612),
#  'ADV->CCONJ->ADJ': np.float64(2.4976638320359534e-05),
#  'CCONJ->ADJ->PUNCT': np.float64(0.704723817563598),
#  'ADJ->PUNCT->AUX': np.float64(0.5482819626760621),
#  'AUX->VERB->ADJ': np.float64(0.29564751822562824),
#  'VERB->ADJ->NOUN': np.float64(0.26169117233558353),
#  'ADJ->NOUN->SCONJ': np.float64(0.580322678708581),
#  'NOUN->SCONJ->DET': np.float64(0.5399508179293175),
#  'SCONJ->DET->NOUN': np.float64(0.36604415793740785),
#  'DET->ADJ->PUNCT': np.float64(0.5600266310486478),
#  'ADJ->PUNCT->NOUN': np.float64(0.3522943336575783),
#  'PUNCT->NOUN->PUNCT': np.float64(0.608454168896404),
#  'PUNCT->AUX->ADV': np.float64(0.6435283439039758),
#  'AUX->ADV->VERB': np.float64(0.28014745231082666),
#  'ADV->VERB->PUNCT': np.float64(0.5549429447525918),
#  'VERB->PUNCT->VERB': np.float64(0.38902020718573804),
#  'PUNCT->VERB->ADP': np.float64(0.5320547257147765),
#  'VERB->ADV->PUNCT': np.float64(0.5353566745733196),
#  'ADV->PUNCT->DET': np.float64(0.6336388766682488),
#  'ADP->PRON->ADP': np.float64(0.6433753185909606),
#  'ADP->PRON->NUM': np.float64(0.4645014032035667),
#  'PRON->NUM->PUNCT': np.float64(0.8325546104362479),
#  'NUM->PUNCT->ADJ': np.float64(0.8325546104362479),
#  'ADJ->PUNCT->ADJ': np.float64(0.5417069506410088),
#  'PUNCT->ADJ->PUNCT': np.float64(0.6558346176624034),
#  'PUNCT->ADJ->CCONJ': np.float64(0.4995000178114069),
#  'ADJ->CCONJ->ADJ': np.float64(0.4052040180087101),
#  'CCONJ->ADJ->NOUN': np.float64(0.21035365932361147),
#  'DET->NOUN->PRON': np.float64(0.23007780455810445),
#  'NOUN->PRON->AUX': np.float64(0.5206757060964363),
#  'AUX->ADV->ADV': np.float64(0.5491706524282879),
#  'ADV->ADV->VERB': np.float64(0.33672468099977326),
#  'ADV->VERB->SCONJ': np.float64(0.5961041020592337),
#  'VERB->SCONJ->PART': np.float64(0.832554610436248),
#  'SCONJ->PART->VERB': np.float64(0.37440286167702547),
#  'NOUN->ADP->ADJ': np.float64(0.2931025551283913),
#  'ADP->ADJ->NOUN': np.float64(0.22869782855573476),
#  'PUNCT->CCONJ->AUX': np.float64(0.4718883999950189),
#  'CCONJ->AUX->VERB': np.float64(0.35684804149685817),
#  'AUX->VERB->CCONJ': np.float64(0.5193174916734756),
#  'VERB->CCONJ->VERB': np.float64(0.39105679566394635),
#  'CCONJ->VERB->PUNCT': np.float64(0.613614560815272),
#  'VERB->PUNCT->SCONJ': np.float64(0.5548939466322842),
#  'PUNCT->SCONJ->PUNCT': np.float64(0.6946933232301307),
#  'SCONJ->PUNCT->VERB': np.float64(0.8325546078088542),
#  'PRON->ADP->ADJ': np.float64(0.527186957351254),
#  'PUNCT->CCONJ->NOUN': np.float64(0.2979919450289679),
#  'CCONJ->NOUN->PUNCT': np.float64(0.5999133449222914),
#  'CCONJ->DET->NOUN': np.float64(0.2625985951835002),
#  'ADJ->NOUN->PRON': np.float64(0.27663793622340765),
#  'VERB->PUNCT->CCONJ': np.float64(0.5047524865736122),
#  'PUNCT->CCONJ->PRON': np.float64(0.20693048817702703),
#  'CCONJ->PRON->CCONJ': np.float64(0.5265537677341674),
#  'PRON->CCONJ->VERB': np.float64(0.3997396558101529),
#  'CCONJ->VERB->ADP': np.float64(0.5014284520065053),
#  'VERB->ADP->NUM': np.float64(0.3603499364691745),
#  'ADP->NUM->ADP': np.float64(0.6786473494685753),
#  'NUM->ADP->ADJ': np.float64(0.5220295852134975),
#  'PUNCT->CCONJ->VERB': np.float64(0.34625428175971584),
#  'NOUN->SCONJ->ADP': np.float64(0.832554609777859),
#  'SCONJ->ADP->ADJ': np.float64(0.557887693728579),
#  'ADJ->NOUN->CCONJ': np.float64(0.4284798126365606),
#  'CCONJ->NOUN->PRON': np.float64(0.3463794490437746),
#  'NOUN->PRON->VERB': np.float64(0.372282508667646),
#  'PRON->VERB->PUNCT': np.float64(0.4490004993233403),
#  'ADV->PUNCT->ADP': np.float64(0.6398820203977009),
#  'DET->NOUN->CCONJ': np.float64(0.516590055878861),
#  'PUNCT->VERB->ADV': np.float64(0.39907833297413575),
#  'VERB->ADV->PART': np.float64(0.832554610436248),
#  'ADV->PART->VERB': np.float64(0.37185176761366295),
#  'VERB->PRON->NOUN': np.float64(0.2409443350393398),
#  'VERB->ADP->CCONJ': np.float64(0.6874127637300014),
#  'ADP->CCONJ->VERB': np.float64(0.2808003693017373),
#  'SCONJ->PUNCT->SCONJ': np.float64(0.8325546084592237),
#  'PUNCT->SCONJ->ADV': np.float64(0.6377989920279262),
#  'SCONJ->ADV->VERB': np.float64(0.37926380727098613),
#  'ADV->VERB->ADP': np.float64(0.5209912229218929),
#  'VERB->ADP->ADP': np.float64(0.5149394536887273),
#  'ADP->ADP->PRON': np.float64(0.3355081257431853),
#  'PUNCT->VERB->PUNCT': np.float64(0.5678924121986778),
#  'DET->ADV->ADJ': np.float64(0.46522698195147194),
#  'ADV->ADJ->NOUN': np.float64(0.2133879531033351),
#  'SCONJ->DET->ADJ': np.float64(0.531458374950951),
#  'ADP->NOUN->NOUN': np.float64(0.353528357429844),
#  'NOUN->NOUN->AUX': np.float64(0.5738930874899848),
#  'NOUN->AUX->ADP': np.float64(0.6205767275288049),
#  'AUX->ADP->PRON': np.float64(0.4241464656372401),
#  'CCONJ->ADV->PUNCT': np.float64(0.7013464299206452),
#  'ADV->PUNCT->PRON': np.float64(0.3826249893791928),
#  'VERB->PUNCT->DET': np.float64(0.6274957215791267),
#  'ADJ->PUNCT->CCONJ': np.float64(0.5098221065917213),
#  'PUNCT->CCONJ->PUNCT': np.float64(0.6990180165849753),
#  'CCONJ->PUNCT->PRON': np.float64(0.6355780345608434),
#  'VERB->PUNCT->NOUN': np.float64(0.42887742068701157),
#  'PUNCT->NOUN->AUX': np.float64(0.7262379499388772),
#  'NOUN->AUX->PART': np.float64(0.48241578249590583),
#  'AUX->PART->VERB': np.float64(0.3417135835166606),
#  'PRON->AUX->DET': np.float64(0.5207791165153011),
#  'AUX->DET->NOUN': np.float64(0.15949552374498582),
#  'NOUN->PUNCT->NOUN': np.float64(0.3383965477285631),
#  'PUNCT->PRON->PUNCT': np.float64(0.6336878452602667),
#  'PRON->PUNCT->PRON': np.float64(0.4584368648931229),
#  'NOUN->PUNCT->ADJ': np.float64(0.506586224707227),
#  'ADJ->NOUN->NOUN': np.float64(0.2452486414305173),
#  'AUX->VERB->ADV': np.float64(0.35036066086287787),
#  'ADV->PUNCT->CCONJ': np.float64(0.520679504025359),
#  'CCONJ->PRON->AUX': np.float64(0.4714321042589937),
#  'PRON->AUX->AUX': np.float64(0.5383471608775132),
#  'AUX->AUX->NOUN': np.float64(0.5920772340933417),
#  'AUX->NOUN->PUNCT': np.float64(0.6307069608141167),
#  'PUNCT->PRON->AUX': np.float64(0.4640692296429524),
#  'PRON->AUX->PART': np.float64(0.39715871344092113),
#  'PART->VERB->ADP': np.float64(0.5072062793911503),
#  'SCONJ->PRON->ADV': np.float64(0.46935805379998347),
#  'PRON->ADV->ADV': np.float64(0.3969211415759837),
#  'VERB->ADV->ADP': np.float64(0.5318034661500822),
#  'ADV->ADP->PRON': np.float64(0.24022431023994947),
#  'ADP->PRON->PRON': np.float64(0.23447293767637553),
#  'PRON->PRON->VERB': np.float64(0.305902039469831),
#  'ADP->NOUN->PART': np.float64(0.439645208961766),
#  'NOUN->PART->NOUN': np.float64(0.3145479049120148),
#  'PART->NOUN->NOUN': np.float64(0.5450349304380747),
#  'NOUN->NOUN->PRON': np.float64(0.41074615870906994),
#  'NOUN->PRON->PRON': np.float64(0.27930177379110377),
#  'VERB->ADP->PROPN': np.float64(0.4455756121714871),
#  'PROPN->CCONJ->VERB': np.float64(0.4329492435515063),
#  'CCONJ->VERB->PRON': np.float64(0.30743527464758197),
#  'VERB->PRON->ADV': np.float64(0.40785503127575456),
#  'PRON->ADV->ADP': np.float64(0.6306952398499085),
#  'ADP->PRON->PUNCT': np.float64(0.6007851151517876),
#  'ADV->PUNCT->ADJ': np.float64(0.5100122732563105),
#  'PUNCT->ADJ->ADP': np.float64(0.6277976075926502),
#  'ADJ->ADP->PRON': np.float64(0.19934487960593314),
#  'ADP->PRON->ADJ': np.float64(0.21310691403301046),
#  'PRON->ADJ->PUNCT': np.float64(0.5803567015056404),
#  'ADP->PROPN->ADP': np.float64(0.5547991853126647),
#  'PROPN->ADP->PRON': np.float64(0.40950942294818105),
#  'PROPN->PROPN->AUX': np.float64(0.633257479542009),
#  'PROPN->AUX->CCONJ': np.float64(0.8325546104362479),
#  'AUX->CCONJ->DET': np.float64(0.8325546097564259),
#  'PROPN->PUNCT->CCONJ': np.float64(0.5354527414854536),
#  'PUNCT->CCONJ->DET': np.float64(0.4117030484046012),
#  'VERB->PRON->PRON': np.float64(0.4761168288158464),
#  'PRON->VERB->NOUN': np.float64(0.2990875753548534),
#  'VERB->PRON->ADJ': np.float64(0.16779941630193154),
#  'PRON->ADJ->CCONJ': np.float64(0.6363847277203643),
#  'ADJ->PUNCT->VERB': np.float64(0.5481341637673088),
#  'PUNCT->VERB->CCONJ': np.float64(0.626948277898426),
#  'ADP->NOUN->CCONJ': np.float64(0.4019492008401228),
#  'NOUN->CCONJ->PART': np.float64(0.8325546097650646),
#  'CCONJ->PART->VERB': np.float64(0.5612898497812125),
#  'PRON->PRON->PRON': np.float64(0.19184193700219473),
#  'PRON->PRON->AUX': np.float64(0.45759651108735766),
#  'AUX->VERB->PART': np.float64(0.621141168981881),
#  'VERB->PART->VERB': np.float64(0.39514708941054877),
#  'VERB->PUNCT->AUX': np.float64(0.6425804068216617),
#  'AUX->ADV->AUX': np.float64(0.6525810370523263),
#  'ADV->AUX->VERB': np.float64(0.32287276369747114),
#  'VERB->ADP->PRON': np.float64(0.25849993113137965),
#  'PRON->ADJ->NOUN': np.float64(0.30040315555381214),
#  'VERB->NOUN->ADP': np.float64(0.5337580766431429),
#  'NOUN->ADP->PUNCT': np.float64(0.7187702998645588),
#  'ADP->PUNCT->ADJ': np.float64(0.6466209848714299),
#  'ADV->DET->ADJ': np.float64(0.5017387864812882),
#  'ADJ->NOUN->AUX': np.float64(0.5469284547864983),
#  'NOUN->AUX->ADJ': np.float64(0.2746833840239027),
#  'AUX->ADJ->ADP': np.float64(0.6046981955827186),
#  'ADJ->ADP->NOUN': np.float64(0.3311711370214444),
#  'NOUN->DET->ADJ': np.float64(0.5065317294366297),
#  'PUNCT->ADV->PRON': np.float64(0.27016843489654346),
#  'ADV->PRON->VERB': np.float64(0.4004955697246526),
#  'PRON->VERB->ADV': np.float64(0.35386195987143365),
#  'VERB->ADV->ADJ': np.float64(0.20042666648526053),
#  'NOUN->NOUN->ADP': np.float64(0.5591273802765778),
#  'ADP->ADJ->PUNCT': np.float64(0.5963053732352315),
#  'ADJ->PUNCT->ADV': np.float64(0.5548376348801336),
#  'PUNCT->ADV->ADJ': np.float64(0.3065509318187032),
#  'ADV->PUNCT->SCONJ': np.float64(0.6343930829349851),
#  'PUNCT->SCONJ->DET': np.float64(0.6125899669838136),
#  'ADJ->NOUN->VERB': np.float64(0.3666625874934161),
#  'NOUN->VERB->ADV': np.float64(0.3945058915689804),
#  'PUNCT->ADV->VERB': np.float64(0.3787602897255071),
#  'ADV->VERB->PRON': np.float64(0.18737887892664257),
#  'PUNCT->PRON->PRON': np.float64(0.17542744454345566),
#  'PRON->VERB->PRON': np.float64(0.23591774543093194),
#  'CCONJ->AUX->AUX': np.float64(0.6902529884108154),
#  'AUX->AUX->ADJ': np.float64(0.44992932937567126),
#  'PRON->PRON->ADV': np.float64(0.3833028649399612),
#  'PRON->ADV->PUNCT': np.float64(0.5723746047068871),
#  'DET->ADJ->ADJ': np.float64(0.4043764316339669),
#  'VERB->PUNCT->PRON': np.float64(0.5260008596267788),
#  'AUX->VERB->NOUN': np.float64(0.36023554522337026),
#  'PRON->VERB->CCONJ': np.float64(0.6192498910251667),
#  'VERB->CCONJ->SCONJ': np.float64(0.5887050105170882),
#  'CCONJ->SCONJ->PUNCT': np.float64(0.7111273641108693),
#  'SCONJ->PUNCT->ADP': np.float64(0.7660422458289703),
#  'PUNCT->ADP->PRON': np.float64(0.22616202876270328),
#  'AUX->AUX->SCONJ': np.float64(0.5641427873482784),
#  'AUX->SCONJ->PRON': np.float64(0.7070598804881182),
#  'AUX->ADV->PUNCT': np.float64(0.4872108099780342),
#  'PRON->NOUN->ADP': np.float64(0.5900749810583947),
#  'NOUN->ADP->VERB': np.float64(0.510744038835854),
#  'NOUN->AUX->AUX': np.float64(0.5045991355066869),
#  'AUX->AUX->ADV': np.float64(0.5592314468682457),
#  'CCONJ->NOUN->ADP': np.float64(0.6723927598482257),
#  'ADP->PROPN->PROPN': np.float64(0.2692571755268314),
#  'DET->PROPN->ADP': np.float64(0.5705996973783655),
#  'PROPN->ADP->DET': np.float64(0.40910583883828744),
#  'ADP->DET->PROPN': np.float64(0.3373166630885285),
#  'PROPN->PUNCT->ADP': np.float64(0.5438790908916072),
#  'PUNCT->ADP->VERB': np.float64(0.4661228619793654),
#  'ADP->VERB->PRON': np.float64(0.2943985893078499),
#  'PART->VERB->NOUN': np.float64(0.3220070155166381),
#  'ADP->PRON->ADV': np.float64(0.3843538238806483),
#  'PRON->ADV->ADJ': np.float64(0.3139081734399856),
#  'PRON->NOUN->PRON': np.float64(0.4049962680519318),
#  'NOUN->PRON->PROPN': np.float64(0.7307657868176232),
#  'PRON->PROPN->PROPN': np.float64(0.6242803040540758),
#  'PROPN->PUNCT->NOUN': np.float64(0.49372786406732844),
#  'PUNCT->NOUN->NOUN': np.float64(0.2976153759678548),
#  'NOUN->NOUN->NOUN': np.float64(0.3368797901269054),
#  'NOUN->NOUN->PROPN': np.float64(0.6728936526207555),
#  'PUNCT->DET->PROPN': np.float64(0.4931046926671925),
#  'ADP->PROPN->NUM': np.float64(0.32845209160071565),
#  'NUM->NOUN->NUM': np.float64(0.8325546097599629),
#  'NOUN->NUM->NOUN': np.float64(0.4512714293829825),
#  'NUM->NOUN->DET': np.float64(0.5709005737944338),
#  'NOUN->DET->PROPN': np.float64(0.7461576811922268),
#  'PROPN->PUNCT->SCONJ': np.float64(0.5843890883469771),
#  'SCONJ->DET->PROPN': np.float64(0.5695420078341217),
#  'DET->PROPN->VERB': np.float64(0.535351774955731),
#  'DET->PROPN->PART': np.float64(0.5440407862492688),
#  'PROPN->PART->PROPN': np.float64(0.3370888070132579),
#  'PART->PROPN->PUNCT': np.float64(0.6018549822002562),
#  'PROPN->PROPN->VERB': np.float64(0.37350917754243707),
#  'PROPN->VERB->ADP': np.float64(0.47782441973346007),
#  'PUNCT->PROPN->VERB': np.float64(0.3622110500385002),
#  'PUNCT->PROPN->ADP': np.float64(0.5857179641483237),
#  'ADP->PROPN->NOUN': np.float64(0.3742321558044344),
#  'PROPN->NOUN->PUNCT': np.float64(0.6179444329087918),
#  'PROPN->PROPN->NUM': np.float64(0.5241116740879065),
#  'NUM->NOUN->CCONJ': np.float64(0.6930308411331755),
#  'CCONJ->DET->ADJ': np.float64(0.5478213364345367),
#  'PROPN->ADP->ADP': np.float64(0.5887050105170882),
#  'ADP->ADP->NOUN': np.float64(0.4385882592139346),
#  'PROPN->ADP->NOUN': np.float64(0.3847639379951489),
#  'NOUN->PUNCT->PROPN': np.float64(0.5031199403798208),
#  'PROPN->ADP->ADJ': np.float64(0.8325546104362479),
#  'PROPN->CCONJ->NOUN': np.float64(0.7600148992996413),
#  'CCONJ->NOUN->NUM': np.float64(2.4976638320359534e-05),
#  'NOUN->PROPN->NOUN': np.float64(0.4648548340939684),
#  'PROPN->NUM->PROPN': np.float64(0.6122826924397611),
#  'NUM->PROPN->NUM': np.float64(0.46450140452505184),
#  'NUM->NOUN->NOUN': np.float64(0.588705010487653),
#  'PROPN->CCONJ->DET': np.float64(0.7114769800530981),
#  'CCONJ->PROPN->NUM': np.float64(0.8325546104362479),
#  'CCONJ->PROPN->PROPN': np.float64(0.3746757269279351),
#  'DET->PROPN->NOUN': np.float64(0.34565201660736433),
#  'NOUN->PROPN->DET': np.float64(0.8325546104362479),
#  'PROPN->DET->ADJ': np.float64(0.4300447353633184),
#  'ADJ->PROPN->NUM': np.float64(0.8325546104362479),
#  'NUM->NOUN->PRON': np.float64(0.27830812451071807),
#  'VERB->NOUN->CCONJ': np.float64(0.4496360295756147),
#  'PROPN->CCONJ->PRON': np.float64(0.5216186119023889),
#  'ADJ->PUNCT->PRON': np.float64(0.4912584340702413),
#  'PRON->NOUN->AUX': np.float64(0.6514269733326442),
#  'AUX->DET->PROPN': np.float64(0.529830108369579),
#  'PROPN->PUNCT->PRON': np.float64(0.31882075023775697),
#  'PRON->NOUN->PART': np.float64(0.5556156054496595),
#  'ADV->ADV->SCONJ': np.float64(0.5553896965940818),
#  'ADV->SCONJ->SCONJ': np.float64(0.6842610041038157),
#  'SCONJ->SCONJ->PRON': np.float64(0.2822449839954867),
#  'PROPN->AUX->DET': np.float64(0.5218693296844709),
#  'VERB->PRON->VERB': np.float64(0.37572117655778053),
#  'PRON->PRON->PUNCT': np.float64(0.674373327273879),
#  'PRON->PUNCT->AUX': np.float64(0.7122788273649294),
#  'AUX->ADV->ADJ': np.float64(0.15980749751108467),
#  'ADV->ADJ->CCONJ': np.float64(0.47146893964832864),
#  'PRON->AUX->ADJ': np.float64(0.24643141955148917),
#  'AUX->ADJ->NOUN': np.float64(0.4519051521885729),
#  'PROPN->PART->PUNCT': np.float64(0.8325546104362479),
#  'PART->PUNCT->DET': np.float64(0.8325546104362479),
#  'PUNCT->DET->ADV': np.float64(0.39884525898714623),
#  'DET->ADV->ADV': np.float64(0.6741323055032299),
#  'ADV->ADV->PUNCT': np.float64(0.5403438802259886),
#  'VERB->NOUN->NOUN': np.float64(0.44906954970255214),
#  'PUNCT->SCONJ->ADP': np.float64(0.6088927164337117),
#  'SCONJ->ADP->NUM': np.float64(0.46450140452505184),
#  'ADP->NUM->NOUN': np.float64(0.2839474423923794),
#  'NUM->NOUN->PUNCT': np.float64(0.6230282686241534),
#  'ADV->ADP->NOUN': np.float64(0.23172349123869787),
#  'ADP->DET->DET': np.float64(0.5550530966815114),
#  'PART->PROPN->PROPN': np.float64(0.5265537677162724),
#  'CCONJ->PROPN->PART': np.float64(0.832554609756426),
#  'PRON->VERB->SCONJ': np.float64(0.5807299057675986),
#  'VERB->SCONJ->PRON': np.float64(0.24841147608575762),
#  'PRON->ADJ->ADP': np.float64(0.6320860839781992),
#  'ADJ->ADP->DET': np.float64(0.5799835054223106),
#  'NOUN->AUX->ADV': np.float64(0.5578019901084559),
#  'CCONJ->PRON->PROPN': np.float64(0.8325546104362479),
#  'PRON->PROPN->NOUN': np.float64(0.5021006085124617),
#  'PRON->VERB->PART': np.float64(0.4835734011564261),
#  'PART->VERB->ADV': np.float64(0.4012671951091309),
#  'VERB->ADV->ADV': np.float64(0.35478965859480605),
#  'VERB->PROPN->CCONJ': np.float64(0.8325546104362479),
#  'CCONJ->PROPN->ADP': np.float64(0.8325546090974179),
#  'NOUN->ADV->ADJ': np.float64(0.1812820699823434),
#  'ADV->ADJ->ADP': np.float64(0.5486274702032526),
#  'ADP->PRON->AUX': np.float64(0.6753942170806202),
#  'CCONJ->PRON->VERB': np.float64(0.3809570322280055),
#  'ADJ->PUNCT->PROPN': np.float64(0.5589545299730474),
#  'PROPN->VERB->DET': np.float64(0.4718824231472007),
#  'PRON->PUNCT->CCONJ': np.float64(0.5115323769620616),
#  'CCONJ->ADV->PART': np.float64(0.7600148993072414),
#  'PART->VERB->PUNCT': np.float64(0.5445896768427797),
#  'VERB->PUNCT->PROPN': np.float64(0.3539611904313121),
#  'SCONJ->PUNCT->PRON': np.float64(0.3715811902201684),
#  'AUX->VERB->DET': np.float64(0.5186944031765267),
#  'PRON->PUNCT->VERB': np.float64(0.3987775432356972),
#  'ADV->AUX->ADJ': np.float64(0.5887050105170882),
#  'AUX->ADJ->PUNCT': np.float64(0.6157902881922614),
#  'ADJ->PUNCT->DET': np.float64(0.687094540237745),
#  'DET->NOUN->ADV': np.float64(0.46048382514097774),
#  'ADV->ADV->ADP': np.float64(0.6152172279044164),
#  'ADP->ADJ->ADP': np.float64(0.5308908758212526),
#  'PUNCT->CCONJ->NUM': np.float64(0.7174930325772461),
#  'CCONJ->NUM->CCONJ': np.float64(0.8325546097599628),
#  'NUM->CCONJ->NUM': np.float64(0.5085247585254734),
#  'CCONJ->NUM->PUNCT': np.float64(0.6912669094653691),
#  'NUM->PUNCT->PRON': np.float64(0.4402957808836),
#  'NOUN->ADP->SCONJ': np.float64(0.586648605590187),
#  'ADP->SCONJ->VERB': np.float64(0.5887050105170882),
#  'SCONJ->VERB->PUNCT': np.float64(0.6418563759875119),
#  'CCONJ->PRON->PRON': np.float64(0.3487861048702423),
#  'DET->NOUN->PART': np.float64(0.4873600276642525),
#  'NOUN->PART->VERB': np.float64(0.3446269499574919),
#  'PART->VERB->AUX': np.float64(0.4806756280590529),
#  'VERB->AUX->ADV': np.float64(0.7707957903035532),
#  'AUX->ADV->NUM': np.float64(0.3616794664051608),
#  'ADV->NUM->PUNCT': np.float64(0.7446594792806364),
#  'NUM->PUNCT->AUX': np.float64(0.8325546097650646),
#  'PUNCT->AUX->SCONJ': np.float64(0.8325546104362479),
#  'AUX->SCONJ->PROPN': np.float64(0.5887050105170883),
#  'SCONJ->PROPN->VERB': np.float64(0.5794000977398719),
#  'PROPN->VERB->PRON': np.float64(0.44253230564555984),
#  'ADV->SCONJ->PRON': np.float64(0.25319697885327347),
#  'PRON->AUX->ADP': np.float64(0.5791858216206666),
#  'PRON->ADJ->ADV': np.float64(0.612282691531925),
#  'ADJ->ADV->VERB': np.float64(0.8325546097564259),
#  'ADV->VERB->PROPN': np.float64(0.5887050105170882),
#  'PUNCT->ADP->ADP': np.float64(0.667193623539318),
#  'ADP->ADP->DET': np.float64(0.6426346741503964),
#  'NOUN->ADP->NUM': np.float64(0.39867113584601743),
#  'CCONJ->AUX->ADV': np.float64(0.6259701096950923),
#  'CCONJ->PUNCT->ADV': np.float64(0.4424523605867517),
#  'VERB->ADP->ADJ': np.float64(0.31535190972285204),
#  'CCONJ->VERB->CCONJ': np.float64(0.6961653314623888),
#  'ADP->ADJ->ADJ': np.float64(0.4134748394056275),
#  'DET->ADJ->ADV': np.float64(0.602896860939769),
#  'ADJ->ADV->ADV': np.float64(0.6448940271715001),
#  'VERB->ADP->ADV': np.float64(0.5164477266407028),
#  'ADP->ADV->VERB': np.float64(0.48868141052916503),
#  'DET->ADJ->CCONJ': np.float64(0.5103652592145442),
#  'ADJ->CCONJ->ADV': np.float64(0.608291141443241),
#  'CCONJ->ADV->VERB': np.float64(0.3734941167772392),
#  'ADV->VERB->NOUN': np.float64(0.33581753793947394),
#  'NOUN->CCONJ->ADJ': np.float64(0.33726421218391633),
#  'ADP->ADP->ADJ': np.float64(0.3301605002430197),
#  'CCONJ->VERB->ADJ': np.float64(0.5567765581493377),
#  'NOUN->NOUN->PUNCT': np.float64(0.616940119789841),
#  'ADJ->CCONJ->NOUN': np.float64(0.4203880630000315),
#  'CCONJ->NOUN->AUX': np.float64(0.5818456105604596),
#  'ADV->AUX->AUX': np.float64(0.6277040587848769),
#  'AUX->AUX->VERB': np.float64(0.2952135815528013),
#  'PRON->AUX->PUNCT': np.float64(0.5246773991827551),
#  'AUX->PUNCT->VERB': np.float64(0.5887050086606346),
#  'DET->ADJ->ADP': np.float64(0.6636174840065676),
#  'ADJ->ADP->ADJ': np.float64(0.39927676996459904),
#  'VERB->PART->ADV': np.float64(0.6741323046818354),
#  'PART->ADV->PRON': np.float64(0.8325546097564259),
#  'ADV->PRON->NOUN': np.float64(0.5059017125939727),
#  'X->PROPN->NUM': np.float64(2.4976638320359534e-05),
#  'PROPN->NUM->PUNCT': np.float64(0.6737304039566815),
#  'ADV->VERB->ADJ': np.float64(0.4059941816052279),
#  'ADV->PUNCT->PUNCT': np.float64(0.8186904214156819),
#  'NOUN->DET->NOUN': np.float64(0.40147234487621614),
#  'NUM->ADJ->NOUN': np.float64(0.39757777578378095),
#  'CCONJ->NOUN->NOUN': np.float64(0.28343180908575927),
#  'ADP->NUM->CCONJ': np.float64(0.5510125814121589),
#  'CCONJ->NUM->NOUN': np.float64(0.4291020019981558),
#  'ADP->VERB->ADJ': np.float64(0.5431310704717202),
#  'PUNCT->CCONJ->ADJ': np.float64(0.47202528109537767),
#  'VERB->ADP->VERB': np.float64(0.3967001558439525),
#  'ADP->VERB->NOUN': np.float64(0.3481058502238294),
#  'PUNCT->NOUN->VERB': np.float64(0.43403349721447954),
#  'ADJ->ADP->PUNCT': np.float64(0.6741323055640912),
#  'ADP->PUNCT->CCONJ': np.float64(0.6706884064861607),
#  'CCONJ->VERB->DET': np.float64(0.677991868652567),
#  'VERB->DET->VERB': np.float64(0.7368582698310494),
#  'DET->VERB->NOUN': np.float64(0.31449224230671197),
#  'VERB->PRON->SCONJ': np.float64(0.5567962023785066),
#  'PRON->SCONJ->DET': np.float64(0.6538897494757117),
#  'AUX->VERB->VERB': np.float64(0.333590232898049),
#  'VERB->VERB->VERB': np.float64(0.7172391701779757),
#  'VERB->VERB->ADP': np.float64(0.6064306278743082),
#  'NOUN->ADV->DET': np.float64(0.8325546091049644),
#  'ADP->DET->VERB': np.float64(0.42987366749199135),
#  'ADP->NOUN->VERB': np.float64(0.4197121781750064),
#  'CCONJ->PUNCT->ADP': np.float64(0.6157526447207339),
#  'PUNCT->ADP->ADJ': np.float64(0.3857079002967192),
#  'NOUN->ADV->VERB': np.float64(0.3249023940530729),
#  'ADV->VERB->ADV': np.float64(0.35605105947263704),
#  'VERB->ADV->DET': np.float64(0.5266397718728433),
#  'PUNCT->VERB->ADJ': np.float64(0.40029337059573117),
#  'DET->NOUN->NOUN': np.float64(0.30812191908866443),
#  'NOUN->NOUN->VERB': np.float64(0.44065863170308717),
#  'NOUN->VERB->VERB': np.float64(0.20396318094314192),
#  'VERB->VERB->PUNCT': np.float64(0.7284268593767937),
#  'NOUN->VERB->PUNCT': np.float64(0.535541660122274),
#  'NOUN->VERB->ADJ': np.float64(0.3453102680187788),
#  'VERB->ADJ->PUNCT': np.float64(0.6294777059536336),
#  'ADJ->PUNCT->SCONJ': np.float64(0.577049803547699),
#  'ADV->VERB->CCONJ': np.float64(0.5730736476882324),
#  'ADJ->ADJ->CCONJ': np.float64(0.2823014805943787),
#  'ADJ->NOUN->DET': np.float64(0.42050443297325896),
#  'CCONJ->ADV->ADV': np.float64(0.5301210085321967),
#  'CCONJ->ADP->ADJ': np.float64(0.39678217479495526),
#  'CCONJ->ADV->ADJ': np.float64(0.49073852778661325),
#  'PUNCT->AUX->ADJ': np.float64(0.5109521258248757),
#  'AUX->ADJ->CCONJ': np.float64(0.6185053996337155),
#  'AUX->ADP->DET': np.float64(0.5756526934607494),
#  'DET->PRON->PUNCT': np.float64(0.8325546084443982),
#  'PRON->PUNCT->ADJ': np.float64(0.48856198295781705),
#  'SCONJ->PRON->PUNCT': np.float64(0.7439096077721908),
#  'CCONJ->ADJ->PART': np.float64(0.6167622444430799),
#  'AUX->ADV->DET': np.float64(0.7189236367254592),
#  'ADJ->ADP->SCONJ': np.float64(0.832554609756426),
#  'SCONJ->VERB->ADP': np.float64(0.7238411057392814),
#  'NOUN->VERB->NOUN': np.float64(0.4031993433181768),
#  'PUNCT->ADJ->SCONJ': np.float64(0.6122826925196727),
#  'ADJ->SCONJ->PRON': np.float64(0.394607457396436),
#  'SCONJ->PRON->NOUN': np.float64(0.4274923920085388),
#  'NOUN->PUNCT->NUM': np.float64(0.5171619326703634),
#  'PUNCT->NUM->ADP': np.float64(0.6632251902453027),
#  'NUM->ADP->DET': np.float64(0.37960926072764045),
#  'NOUN->NOUN->CCONJ': np.float64(0.6944577000297523),
#  'PRON->PUNCT->ADV': np.float64(0.42248056179136134),
#  'PUNCT->ADV->NUM': np.float64(0.3096090113501021),
#  'ADV->NUM->NOUN': np.float64(0.43298604295238774),
#  'CCONJ->ADJ->ADP': np.float64(0.6604569500888563),
#  'ADP->DET->NUM': np.float64(0.27302355039743925),
#  'DET->NUM->PUNCT': np.float64(0.7008334020684953),
#  'DET->ADJ->AUX': np.float64(0.7433460768762312),
#  'ADJ->AUX->ADJ': np.float64(2.4976638320359534e-05),
#  'VERB->ADP->PUNCT': np.float64(0.5262402023574788),
#  'VERB->ADV->SCONJ': np.float64(0.5609666118614988),
#  'VERB->NOUN->SCONJ': np.float64(0.5250925260081685),
#  'NOUN->SCONJ->CCONJ': np.float64(0.8325546104362479),
#  'SCONJ->CCONJ->PRON': np.float64(2.4976638320359534e-05),
#  'PUNCT->VERB->PART': np.float64(0.5493174649183448),
#  'PUNCT->PRON->ADV': np.float64(0.31029277156178203),
#  'PRON->ADV->VERB': np.float64(0.2986804680304451),
#  'VERB->NUM->NOUN': np.float64(0.3222972899417559),
#  'VERB->PART->CCONJ': np.float64(0.8325546104362479),
#  'PART->CCONJ->VERB': np.float64(0.8325546097564259),
#  'ADP->NOUN->SCONJ': np.float64(0.6896251838504408),
#  'NOUN->ADV->AUX': np.float64(0.8325546090967058),
#  'ADV->AUX->ADV': np.float64(0.7600149000215485),
#  'ADV->ADJ->SCONJ': np.float64(0.5185713074885381),
#  'CCONJ->ADV->SCONJ': np.float64(0.6981617007221662),
#  'NOUN->PUNCT->PART': np.float64(0.6880098131525979),
#  'PUNCT->PART->VERB': np.float64(0.4291672455261647),
#  'VERB->PRON->PUNCT': np.float64(0.5218389887046057),
#  'PUNCT->ADV->SCONJ': np.float64(0.6285506522125711),
#  'ADP->ADJ->VERB': np.float64(0.5098334943167172),
#  'ADJ->VERB->NOUN': np.float64(0.3560878437325222),
#  'PUNCT->SCONJ->VERB': np.float64(0.5119505441002883),
#  'ADV->VERB->DET': np.float64(0.5042653870148432),
#  'PART->VERB->ADJ': np.float64(0.37510429414597773),
#  'VERB->ADJ->CCONJ': np.float64(0.5361528881839557),
#  'ADJ->CCONJ->PRON': np.float64(0.8325546084443982),
#  'CCONJ->PRON->ADJ': np.float64(0.5624855338292845),
#  'PUNCT->SCONJ->SCONJ': np.float64(0.6340725833863995),
#  'SCONJ->SCONJ->DET': np.float64(0.6483439601015161),
#  'ADJ->PROPN->AUX': np.float64(0.5740937952909162),
#  'PROPN->AUX->VERB': np.float64(0.35935936661215223),
#  'ADP->ADV->ADV': np.float64(0.3541646911664204),
#  'NOUN->CCONJ->ADP': np.float64(0.6118756285382657),
#  'CCONJ->ADP->PRON': np.float64(0.4131667180680602),
#  'NOUN->ADP->ADP': np.float64(0.47505084078941384),
#  'NOUN->CCONJ->VERB': np.float64(0.3261720753542675),
#  'SCONJ->PUNCT->ADV': np.float64(0.42866330521503865),
#  'AUX->PART->PUNCT': np.float64(0.5718767373913203),
#  'PART->PUNCT->PRON': np.float64(0.5641427873687562),
#  'VERB->PART->PUNCT': np.float64(0.7574963840392572),
#  'PART->PUNCT->VERB': np.float64(0.48856198294309616),
#  'PRON->NOUN->VERB': np.float64(0.37457548415623765),
#  'NOUN->VERB->PRON': np.float64(0.2966525441361003),
#  'PRON->NOUN->DET': np.float64(0.5632560774775013),
#  'CCONJ->SCONJ->PRON': np.float64(0.31029159219344893),
#  'PRON->VERB->ADJ': np.float64(0.32303291180684596),
#  'VERB->ADJ->ADJ': np.float64(0.39213653612955673),
#  'ADJ->ADJ->ADV': np.float64(0.8325546097564259),
#  'PUNCT->PRON->NOUN': np.float64(0.36638397008412044),
#  'ADP->PRON->CCONJ': np.float64(0.6750845431755064),
#  'PRON->CCONJ->DET': np.float64(0.7307657876189769),
#  'CCONJ->AUX->ADP': np.float64(0.8325546104362479),
#  'ADP->VERB->NUM': np.float64(0.5887050105170882),
#  'PRON->ADP->ADP': np.float64(0.5183745668169969),
#  'PUNCT->AUX->DET': np.float64(0.4347913550439538),
#  'AUX->DET->ADV': np.float64(0.8325546104362479),
#  'PRON->AUX->PRON': np.float64(0.28302874857503885),
#  'AUX->PRON->ADP': np.float64(0.6840077302660846),
#  'ADJ->CCONJ->VERB': np.float64(0.5828076606157708),
#  'CCONJ->VERB->ADV': np.float64(0.38527290429847055),
#  'ADV->ADV->ADV': np.float64(0.36492179472726755),
#  'ADV->ADV->CCONJ': np.float64(0.4594896425477522),
#  'ADV->CCONJ->ADV': np.float64(0.5004365122640972),
#  'CCONJ->SCONJ->ADP': np.float64(0.8325546097698272),
#  'SCONJ->ADP->DET': np.float64(0.4336185192241984),
#  'VERB->PUNCT->ADJ': np.float64(0.455930072400736),
#  'ADJ->SCONJ->DET': np.float64(0.6080119186432665),
#  'NOUN->VERB->PART': np.float64(0.6064041998860887),
#  'PART->VERB->SCONJ': np.float64(0.5646213887510776),
#  'AUX->PART->ADV': np.float64(0.715505043099642),
#  'PART->ADV->VERB': np.float64(0.5755484822319977),
#  'PRON->AUX->SCONJ': np.float64(0.6277040579045792),
#  'ADP->ADV->PUNCT': np.float64(0.5134884625031279),
#  'AUX->ADP->ADJ': np.float64(0.5619168169795339),
#  'ADP->PRON->DET': np.float64(0.6260201925217936),
#  'PRON->DET->NOUN': np.float64(0.2649676770497561),
#  'ADV->VERB->AUX': np.float64(0.8325546091009547),
#  'ADJ->ADP->PROPN': np.float64(0.41117482990047677),
#  'VERB->ADV->CCONJ': np.float64(0.6290999779095637),
#  'ADV->CCONJ->VERB': np.float64(0.4191188706940215),
#  'AUX->VERB->SCONJ': np.float64(0.6030144999389849),
#  'VERB->SCONJ->ADP': np.float64(0.7661993752117165),
#  'PART->AUX->VERB': np.float64(0.3812369533926999),
#  'PART->VERB->PART': np.float64(0.30905358960967727),
#  'PRON->PRON->NOUN': np.float64(0.5537363198867484),
#  'ADV->ADP->PUNCT': np.float64(0.7446594800006302),
#  'PRON->ADV->CCONJ': np.float64(0.5887050095703924),
#  'ADV->CCONJ->DET': np.float64(0.4645014031594728),
#  'PRON->NOUN->ADV': np.float64(0.5363911653406632),
#  'NOUN->ADV->ADP': np.float64(0.5675096958835103),
#  'ADV->ADP->NUM': np.float64(0.2891104143614266),
#  'ADP->VERB->ADP': np.float64(0.5694238146367019),
#  'ADV->ADV->PART': np.float64(0.4645014031594728),
#  'AUX->ADV->NOUN': np.float64(0.363736337138912),
#  'AUX->VERB->NUM': np.float64(0.28373280379417787),
#  'AUX->PRON->AUX': np.float64(0.6293521281584803),
#  'PRON->AUX->CCONJ': np.float64(0.7307657868320887),
#  'AUX->CCONJ->VERB': np.float64(0.6797779927131481),
#  'NUM->ADP->PRON': np.float64(0.3433038183954951),
#  'NOUN->VERB->SCONJ': np.float64(0.6838796043694736),
#  'VERB->SCONJ->SCONJ': np.float64(0.6266591306206327),
#  'ADP->PUNCT->PRON': np.float64(0.5702971251314991),
#  'NOUN->AUX->CCONJ': np.float64(0.5887050105170882),
#  'AUX->CCONJ->AUX': np.float64(0.832554610436248),
#  'ADJ->NOUN->PART': np.float64(0.4746538710935003),
#  'VERB->PRON->CCONJ': np.float64(0.5515612145858318),
#  'PUNCT->SCONJ->AUX': np.float64(0.43930239489393735),
#  'SCONJ->AUX->DET': np.float64(0.5641427873482784),
#  'CCONJ->ADP->ADV': np.float64(0.6158543618845231),
#  'NOUN->PRON->ADJ': np.float64(0.4162773047499585),
#  'DET->ADJ->VERB': np.float64(0.5930372039481394),
#  'ADJ->VERB->PRON': np.float64(0.6029622641481264),
#  'ADV->ADP->ADV': np.float64(0.550836889287476),
#  'ADP->ADV->NUM': np.float64(0.09444262375970483),
#  'SCONJ->ADV->PRON': np.float64(0.3394011394200049),
#  'AUX->ADJ->NUM': np.float64(0.5887050105170882),
#  'ADJ->NUM->PROPN': np.float64(0.8325546104362479),
#  'NUM->PROPN->NOUN': np.float64(0.5641427873482784),
#  'NUM->PUNCT->CCONJ': np.float64(0.693524178996255),
#  'AUX->ADV->ADP': np.float64(0.5816031555548954),
#  'PRON->AUX->NOUN': np.float64(0.4482161824751358),
#  'AUX->NOUN->VERB': np.float64(0.5971945621187577),
#  'ADP->PRON->VERB': np.float64(0.3220873906829725),
#  'CCONJ->VERB->SCONJ': np.float64(0.6122826907470696),
#  'AUX->AUX->ADP': np.float64(0.6738911927539654),
#  'VERB->ADV->PRON': np.float64(0.4639738595938838),
#  'ADV->PRON->PRON': np.float64(0.37926380885037386),
#  'CCONJ->PRON->ADV': np.float64(0.4634920982186964),
#  'VERB->SCONJ->PUNCT': np.float64(0.7938096717738095),
#  'DET->NOUN->ADJ': np.float64(0.3473001896677857),
#  'NOUN->ADJ->PUNCT': np.float64(0.5911950681897126),
#  'NOUN->PRON->NOUN': np.float64(0.7133359445945208),
#  'NOUN->ADV->NUM': np.float64(0.345465493182503),
#  'NUM->PUNCT->SCONJ': np.float64(0.5989233946327628),
#  'AUX->ADV->SCONJ': np.float64(0.8325546090974179),
#  'SCONJ->VERB->DET': np.float64(0.6797779918975341),
#  'ADV->ADP->ADJ': np.float64(0.33012965022132945),
#  'VERB->PROPN->DET': np.float64(0.8325546097599628),
#  'PROPN->DET->NOUN': np.float64(0.48986213749590624),
#  'VERB->ADJ->SCONJ': np.float64(0.6317587140035089),
#  'NOUN->PRON->PUNCT': np.float64(0.6720440415154321),
#  'SCONJ->PRON->ADP': np.float64(0.6325454904000896),
#  'AUX->VERB->PROPN': np.float64(0.4213728390076633),
#  'VERB->PROPN->PROPN': np.float64(0.4652522009488235),
#  'DET->PROPN->CCONJ': np.float64(0.46450140443635896),
#  'DET->ADV->NOUN': np.float64(0.3150049092953013),
#  'ADV->NOUN->ADP': np.float64(0.7036370703866723),
#  'INTJ->PUNCT->PUNCT': np.float64(0.6257096084138736),
#  'PUNCT->PUNCT->PRON': np.float64(0.2996665479878578),
#  'VERB->PUNCT->PUNCT': np.float64(0.6992535810316702),
#  'PROPN->PROPN->SCONJ': np.float64(0.8325546104362479),
#  'PROPN->SCONJ->PRON': np.float64(0.5887050105170883),
#  'PRON->PUNCT->PUNCT': np.float64(0.7918529167942937),
#  'VERB->ADP->PART': np.float64(0.8325546085279003),
#  'ADP->PART->VERB': np.float64(0.5156862106409792),
#  'PRON->SCONJ->PRON': np.float64(0.4248877660234791),
#  'CCONJ->ADJ->ADJ': np.float64(0.5733098649930072),
#  'ADV->PART->AUX': np.float64(0.5237923910540264),
#  'PRON->PUNCT->DET': np.float64(0.5739553952591635),
#  'PUNCT->DET->PRON': np.float64(0.4806756280590529),
#  'DET->PRON->AUX': np.float64(0.6122826915319252),
#  'VERB->PART->AUX': np.float64(0.6277690240720607),
#  'PART->AUX->ADV': np.float64(0.7139769585256407),
#  'SCONJ->SCONJ->VERB': np.float64(0.832554609092316),
#  'AUX->ADP->ADV': np.float64(0.8325546091062026),
#  'ADP->ADV->ADJ': np.float64(0.6355780326692216),
#  'CCONJ->ADJ->DET': np.float64(0.832554610436248),
#  'ADJ->DET->NOUN': np.float64(0.40388445240199944),
#  'VERB->CCONJ->AUX': np.float64(0.6418563750055969),
#  'DET->NUM->CCONJ': np.float64(0.5220295841624838),
#  'NOUN->CCONJ->NUM': np.float64(0.41036881238707085),
#  'VERB->ADV->NUM': np.float64(0.39367656124082684),
#  'CCONJ->VERB->PART': np.float64(0.4356161577294502),
#  'ADP->PUNCT->DET': np.float64(0.6305025175253),
#  'NOUN->AUX->PRON': np.float64(0.3950531188418873),
#  'AUX->PRON->VERB': np.float64(0.36279915034765003),
#  'VERB->DET->ADV': np.float64(0.670653572349966),
#  'CCONJ->ADP->DET': np.float64(0.6445975652507907),
#  'AUX->ADJ->PART': np.float64(0.5619909949259203),
#  'ADP->NOUN->PRON': np.float64(0.3174680549570402),
#  'ADV->VERB->PART': np.float64(0.5919390524134476),
#  'PUNCT->CCONJ->PART': np.float64(0.5410131390234713),
#  'ADV->AUX->PRON': np.float64(0.49964613608906533),
#  'AUX->AUX->DET': np.float64(0.5091991568977867),
#  'PUNCT->ADV->DET': np.float64(0.6330122882666842),
#  'CCONJ->SCONJ->ADJ': np.float64(0.832554608454122),
#  'SCONJ->AUX->PART': np.float64(0.832554609097418),
#  'AUX->PART->NOUN': np.float64(0.8325546104362479),
#  'PART->NOUN->VERB': np.float64(0.7600148985854085),
#  'VERB->NOUN->ADV': np.float64(0.34368519737162456),
#  'AUX->PART->DET': np.float64(0.641856375974013),
#  'PART->DET->NOUN': np.float64(0.4304106399334962),
#  'DET->PROPN->AUX': np.float64(0.53515845527784),
#  'PROPN->AUX->AUX': np.float64(0.618889638032834),
#  'ADV->PUNCT->AUX': np.float64(0.6111446994212643),
#  'PROPN->PROPN->PRON': np.float64(0.7172391693085094),
#  'PRON->NOUN->SCONJ': np.float64(0.6713415324893217),
#  'NOUN->SCONJ->ADV': np.float64(0.832554609092316),
#  'PART->AUX->ADJ': np.float64(0.4053159426538661),
#  'NOUN->PUNCT->X': np.float64(0.6608669204812708),
#  'PUNCT->X->X': np.float64(0.5613475228487079),
#  'X->X->ADP': np.float64(0.8325546104362479),
#  'X->ADP->DET': np.float64(0.5887050105170882),
#  'DET->NOUN->PROPN': np.float64(0.5757355597654044),
#  'PROPN->NOUN->VERB': np.float64(0.49323327445537674),
#  'PROPN->NOUN->NUM': np.float64(2.4272929424270277e-05),
#  'NOUN->NUM->PUNCT': np.float64(0.8325546065277707),
#  'NUM->PUNCT->NUM': np.float64(0.215901328783464),
#  'PROPN->NUM->NUM': np.float64(0.8325546104362479),
#  'NUM->NUM->DET': np.float64(0.832554609756426),
#  'NUM->DET->ADJ': np.float64(0.8325546104362479),
#  'ADJ->PROPN->NOUN': np.float64(0.4110426148728389),
#  'NUM->NOUN->ADV': np.float64(0.37165581362457545),
#  'NOUN->ADV->PRON': np.float64(0.309499110572348),
#  'ADV->PRON->AUX': np.float64(0.4592491279217699),
#  'VERB->SCONJ->DET': np.float64(0.4584074812560579),
#  'CCONJ->ADV->PROPN': np.float64(0.5740937942297627),
#  'ADV->PROPN->VERB': np.float64(0.612282691531925),
#  'ADP->ADV->ADP': np.float64(0.6224965433292792),
#  'AUX->PRON->PUNCT': np.float64(0.5086121462922358),
#  'ADP->NUM->DET': np.float64(0.5971945612093695),
#  'NUM->DET->PUNCT': np.float64(0.5887050105170882),
#  'AUX->PART->PROPN': np.float64(0.3637363402770333),
#  'PUNCT->CCONJ->PROPN': np.float64(0.5969333208486846),
#  'CCONJ->AUX->PRON': np.float64(0.6979665989033659),
#  'AUX->PRON->ADV': np.float64(0.6399777462304004),
#  'PRON->ADV->DET': np.float64(0.832554609756426),
#  'CCONJ->PRON->PUNCT': np.float64(0.7132598657241539),
#  'PROPN->PUNCT->AUX': np.float64(0.547856684828377),
#  'PROPN->PUNCT->VERB': np.float64(0.46218058089304553),
#  'PRON->VERB->VERB': np.float64(0.39309749919188464),
#  'VERB->VERB->ADJ': np.float64(0.6167622424814881),
#  'CCONJ->ADJ->CCONJ': np.float64(0.832554609092316),
#  'PUNCT->AUX->ADP': np.float64(0.8325546084806698),
#  'CCONJ->NUM->ADV': np.float64(0.5887050105170882),
#  'NUM->ADV->DET': np.float64(0.8325546104362479),
#  'PART->PROPN->NOUN': np.float64(0.8325546104362479),
#  'ADV->PUNCT->PROPN': np.float64(0.38766243932940325),
#  'PUNCT->PROPN->CCONJ': np.float64(0.6979665997139831),
#  'PUNCT->SCONJ->PROPN': np.float64(0.49659312295408425),
#  'PROPN->AUX->ADV': np.float64(0.49140430623291165),
#  'ADV->CCONJ->ADP': np.float64(0.5887050105170883),
#  'CCONJ->SCONJ->DET': np.float64(0.7322381685124343),
#  'NOUN->SCONJ->PROPN': np.float64(0.48856198294309616),
#  'SCONJ->PROPN->ADV': np.float64(0.8325546104362479),
#  'PROPN->ADV->CCONJ': np.float64(0.8325546104362479),
#  'DET->ADJ->PRON': np.float64(0.3945656737922273),
#  'ADJ->PRON->AUX': np.float64(0.5577870563820949),
#  'AUX->PART->AUX': np.float64(0.4295126963493175),
#  'PART->AUX->AUX': np.float64(0.6047985941671912),
#  'AUX->AUX->PROPN': np.float64(0.832554610436248),
#  'AUX->PROPN->PUNCT': np.float64(0.570541520511233),
#  'CCONJ->PROPN->CCONJ': np.float64(0.8325546104362479),
#  'CCONJ->PROPN->VERB': np.float64(0.37415958790034903),
#  'PROPN->AUX->PART': np.float64(0.5411086519493886),
#  'CCONJ->PROPN->DET': np.float64(0.3637363402770333),
#  'DET->NOUN->NUM': np.float64(0.3172106805720355),
#  'VERB->SCONJ->PROPN': np.float64(0.5328785030292356),
#  'PROPN->VERB->PUNCT': np.float64(0.5052486913690505),
#  'NOUN->NUM->PRON': np.float64(0.8325546097564259),
#  'NUM->PRON->AUX': np.float64(0.8325546090923162),
#  'CCONJ->PUNCT->PROPN': np.float64(0.4645014008407559),
#  'NOUN->NOUN->ADV': np.float64(0.6000853426785377),
#  'PUNCT->PUNCT->CCONJ': np.float64(0.5035812049178927),
#  'NOUN->NUM->NUM': np.float64(0.832554609092316),
#  'PRON->PROPN->VERB': np.float64(0.8325546097564259),
#  'PROPN->VERB->NOUN': np.float64(0.6986336779553416),
#  'VERB->SCONJ->ADV': np.float64(0.5318286428252907),
#  'SCONJ->ADV->PROPN': np.float64(0.8325546104362479),
#  'ADV->PROPN->NOUN': np.float64(0.8325546104362479),
#  'PROPN->NOUN->ADV': np.float64(0.8325546097564259),
#  'PRON->ADP->PART': np.float64(0.8325546104362479),
#  'PUNCT->PART->ADV': np.float64(0.6418563725071622),
#  'PART->ADV->DET': np.float64(0.6737304073601044),
#  'VERB->AUX->VERB': np.float64(0.3257079872820641),
#  'PROPN->PART->VERB': np.float64(0.5850190119374615),
#  'ADP->PART->INTJ': np.float64(0.8325546104362479),
#  'PART->INTJ->VERB': np.float64(0.8325546104362479),
#  'INTJ->VERB->PUNCT': np.float64(0.8325546104362479),
#  'NOUN->VERB->CCONJ': np.float64(0.7307657860853163),
#  'PART->NOUN->CCONJ': np.float64(0.8325546091009547),
#  'AUX->ADV->PRON': np.float64(0.674132303923003),
#  'ADJ->PUNCT->PUNCT': np.float64(0.7657445308744427),
#  'VERB->NOUN->PART': np.float64(0.7446594814778507),
#  'CCONJ->ADV->PRON': np.float64(0.26328449956781286),
#  'NUM->NOUN->ADP': np.float64(0.6298882508263836),
#  'ADP->PRON->PROPN': np.float64(0.5821768066592028),
#  'VERB->ADJ->ADP': np.float64(0.538714961527737),
#  'CCONJ->NOUN->ADV': np.float64(0.5705415205627797),
#  'ADJ->CCONJ->DET': np.float64(0.6448940280355261),
#  'ADJ->ADJ->PUNCT': np.float64(0.5117893154571893),
#  'PUNCT->NUM->NOUN': np.float64(0.46604111058250225),
#  'NOUN->ADP->AUX': np.float64(0.7555873861584584),
#  'ADP->AUX->ADP': np.float64(0.8325546104362479),
#  'AUX->ADP->NOUN': np.float64(0.4893581927396708),
#  'ADP->NOUN->NUM': np.float64(2.4976638320359534e-05),
#  'ADJ->VERB->DET': np.float64(0.8325546104362479),
#  'NOUN->SCONJ->VERB': np.float64(0.526553769900771),
#  'ADV->ADV->PRON': np.float64(0.2937028491354863),
#  'ADP->AUX->DET': np.float64(0.8325546097599628),
#  'ADV->NOUN->PART': np.float64(0.832554610436248),
#  'NOUN->PART->PRON': np.float64(0.5887050105170882),
#  'PART->PRON->PRON': np.float64(2.4976638320359534e-05),
#  'PUNCT->VERB->PROPN': np.float64(0.4536973310095162),
#  'ADP->ADP->PROPN': np.float64(0.5913259585378127),
#  'PART->ADV->ADJ': np.float64(0.4675957434302026),
#  'PRON->PROPN->PART': np.float64(0.8325546104362479),
#  'VERB->PRON->DET': np.float64(0.5293419557142053),
#  'PRON->DET->VERB': np.float64(0.8325546104362479),
#  'ADP->DET->PUNCT': np.float64(0.8325546091210564),
#  'DET->PUNCT->NOUN': np.float64(0.09518589440202851),
#  'NOUN->AUX->PROPN': np.float64(2.4272929424270277e-05),
#  'PUNCT->PUNCT->SCONJ': np.float64(0.5519288970202039),
#  'PRON->NOUN->NOUN': np.float64(0.4022271935448149),
#  'AUX->PRON->NOUN': np.float64(0.4288420246419224),
#  'PUNCT->ADP->PUNCT': np.float64(0.8325546078528834),
#  'ADP->PUNCT->NOUN': np.float64(0.39332817645442475),
#  'AUX->AUX->AUX': np.float64(0.7545392483497386),
#  'AUX->AUX->PRON': np.float64(0.6122826916102337),
#  'PRON->PUNCT->SCONJ': np.float64(0.4512088937253087),
#  'PRON->ADP->PUNCT': np.float64(0.5740937923408788),
#  'ADJ->PROPN->PROPN': np.float64(0.37345028914433614),
#  'SCONJ->PRON->ADJ': np.float64(0.4636512780064627),
#  'VERB->PROPN->VERB': np.float64(0.47427213401109564),
#  'PROPN->VERB->ADV': np.float64(0.41779320661791447),
#  'PROPN->VERB->PART': np.float64(0.535281677760723),
#  'ADV->ADP->PROPN': np.float64(0.48981876946010805),
#  'ADP->PUNCT->VERB': np.float64(0.4622615591284675),
#  'ADV->ADP->VERB': np.float64(0.3799664076670841),
#  'NOUN->PRON->ADV': np.float64(0.5698554147286872),
#  'PART->NOUN->ADP': np.float64(0.6009494744602318),
#  'SCONJ->ADV->DET': np.float64(0.83255460911313),
#  'PRON->ADP->VERB': np.float64(0.4335232523801253),
#  'VERB->VERB->PRON': np.float64(0.5072148646363649),
#  'PRON->SCONJ->CCONJ': np.float64(0.8325546104362479),
#  'SCONJ->CCONJ->DET': np.float64(0.8325546104362479),
#  'ADV->ADJ->ADV': np.float64(0.5887050105023707),
#  'ADJ->ADV->SCONJ': np.float64(0.46450140452505184),
#  'SCONJ->PRON->PART': np.float64(0.44585154195965016),
#  'PRON->DET->ADV': np.float64(0.5265537687954964),
#  'PART->ADV->ADV': np.float64(0.7723977890846062),
#  'CCONJ->AUX->PART': np.float64(0.6582698186303664),
#  'CCONJ->NOUN->CCONJ': np.float64(0.5787536334848563),
#  'PUNCT->AUX->PART': np.float64(0.3486246930491523),
#  'ADJ->ADP->NUM': np.float64(0.735410857011786),
#  'NUM->DET->PROPN': np.float64(0.6122826925196728),
#  'PROPN->ADP->NUM': np.float64(0.5302523647719678),
#  'ADP->NUM->PROPN': np.float64(0.832554609092316),
#  'NUM->PROPN->PROPN': np.float64(0.8325546104362479),
#  'NOUN->CCONJ->ADV': np.float64(0.5722998563744994),
#  'CCONJ->ADV->ADP': np.float64(0.6578004675709529),
#  'ADP->NOUN->AUX': np.float64(0.6108231271863036),
#  'ADP->PUNCT->PUNCT': np.float64(0.7339707419872424),
#  'PUNCT->PUNCT->VERB': np.float64(0.6045789854860659),
#  ...}
